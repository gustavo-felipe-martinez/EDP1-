# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavo-felipe-martinez/EDP1-/blob/main/graficadeparabola.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <span style='color=red;'>Grafica de una parabola.</span>

# %% [markdown]
# ![edp.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
  return x**2

x_values=np.linspace(-10, 10, 100)
y_values=f(x_values)
plt.plot(x_values, y_values , label="f(x)=x^2", color="blue")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Grafica de f(x)=x^2")
plt.legend()
plt.grid(True)
plt.show()
