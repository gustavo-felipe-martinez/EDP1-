# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavo-felipe-martinez/EDP1-/blob/main/Copia_de_Fourier_sympy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Este es el ejemplo del profesor

# %%
from sympy import fourier_series, pi, plot, Piecewise,exp
from sympy.abc import x

# %%
f=Piecewise(
    (0, x < -2),
    (x+2,(x >= -2) & (x < 0)),
    (0,(x<=2)))

# %%
plot(f, (x,-2,2),line_color ='red')

# %%
s = fourier_series(f, (x, -2, 2))
s1 = s.truncate(n = 3)
s2 = s.truncate(n = 5)
s3 = s.truncate(n = 7)
p = plot(f, s1, s2, s3, (x, -pi, pi), show=False, legend=True)

# %%
p[0].label = 'x'
p[1].label = 'n=3'
p[2].label = 'n=5'
p[3].label = 'n=7'

# %%
p.show()

# %% [markdown]
# Extencion impar

# %%
f=Piecewise(
    (0, x < -1),
    ((-1)*exp(-2*x),(x >= -1) & (x < 0)),
    (exp(2*x),(x >= 0) & (x < 1)),
    (0,(x>=1)))

# %%
plot(f, (x,-2,2),line_color ='red')

# %%
s = fourier_series(f, (x, -1, 1))
s1 = s.truncate(n = 3)
s2 = s.truncate(n = 5)
s3 = s.truncate(n = 7)
p = plot(f, s1, s2, s3, (x, -pi, pi), show=False, legend=True)

# %%
p[0].label = 'x'
p[1].label = 'n=3'
p[2].label = 'n=5'
p[3].label = 'n=7'

# %%
p.show()

# %% [markdown]
# Extencion par

# %%
f=Piecewise(
    (0, x < -1),
    (exp(-2*x),(x >= -1) & (x < 0)),
    (exp(2*x),(x >= 0) & (x < 1)),
    (0,(x>=1)))

# %%
plot(f, (x,-2,2),line_color ='red')

# %%
s = fourier_series(f, (x, -1, 1))
s1 = s.truncate(n = 3)
s2 = s.truncate(n = 5)
s3 = s.truncate(n = 7)
p = plot(f, s1, s2, s3, (x, -pi, pi), show=False, legend=True)

# %%
p[0].label = 'x'
p[1].label = 'n=3'
p[2].label = 'n=5'
p[3].label = 'n=7'

# %%
p.show()

# %%
f=Piecewise(
    (0, x < ((-1)*pi)),
    (-2,(x >= ((-1)*pi)) & (x < (-1)*(pi/2))),
    (-1,(x >= (-1)*(pi/2)) & (x < 0)),
    (1,(x >=0 ) & (x <(pi/2))),
    (2,(x >=(pi/2)) & (x < pi)),
    (0,(x>=pi)))

# %%
plot(f, (x,-2,2),line_color ='red')
